# %%
import pandas as pd

from datetime import datetime
from datetime import date
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # Importa os dados

# %%
df = pd.read_excel(
    "dados.xlsx",
    sheet_name=0,
    header=1,          # usa a 2ª linha como cabeçalho real
    dtype={"Class. Por idade": str},  # evita converter "1" em número se quiser
)

# %% [markdown]
# ## Limpando / Organizando - Dataset

# %%
def limpa_dados(df):
    colunas_data = [
        "data_nascimento",
        "data_primeira_consulta",
        "data_primeira_colonoscopia",
    ]

    def padroniza_colunas(df):
        df.columns = (
            df.columns.astype(str)
            .str.replace("\n", " ", regex=False)
            .str.replace(r"\s+", " ", regex=True)
            .str.strip()
        )
        return df

    def renomeia_colunas(df):
        df = df.rename(columns={
            "Nome": "nome",
            "Class. Por idade": "classificacao_idade",
            "Data nascimento": "data_nascimento",
            "Data 1ª consulta": "data_primeira_consulta",
            "Tempo entre início dos sintomas e primeira consulta": "intervalo_sintomas_primeira_consulta",
            "Sexo": "sexo",
            "Tipo": "tipo",
            "Perda de peso": "perda_peso",
            "Idade (meses) início dos sintomas": "intervalo_nascimento_sintomas",
            "Data 1ª colono": "data_primeira_colonoscopia",
            "Unnamed: 10": "intervalo_sintomas_primeira_colonoscopia",
            "Classificação": "classificacao",
        })
        return df

    def formata_colunas_data(df):
        for coluna in colunas_data:
            df[coluna] = (
                pd.to_datetime(df[coluna], errors="coerce")
                .dt.strftime("%d/%m/%Y")
            )
        return df

    def deixar_coluna_inteira(df, coluna):
        # print(type(df[coluna]).tolist())
        # for i in df[coluna].tolist():
        #     print(i)
        for index, tempo in enumerate(df[coluna].tolist()):
            print('batman',tempo)
            if len(tempo) > 0:
              print(tempo)
              df.loc[index, coluna] = tempo.replace("meses", "")
            else:    
              print(tempo)
              df.loc[index, coluna] = -1   
        df[coluna] = pd.to_numeric(df[coluna], errors="coerce")
        return df
        
    df = df.drop(index=0).reset_index(drop=True)
    # df = df.drop(columns=["nome"])
    df = padroniza_colunas(df)
    df = renomeia_colunas(df)
    df = formata_colunas_data(df)
    df = df.drop(columns=["nome"])
    df = deixar_coluna_inteira(df, "intervalo_sintomas_primeira_consulta")
    
    return df

    
    
    # df = padroniza_colunas(df)
    # df = renomeia_colunas(df)
    # df = formata_colunas_data(df)
    # df = deixar_coluna_inteira(df,'intervalo_sintomas_primeira_consulta')
    # df = df.drop(index=0).reset_index(drop=True)
    # df = df.drop(columns=["nome"])
    # return df



   
   

     # for index,tempo in enumerate(df['intervalo_sintomas_primeira_consulta'].tolist()) : 
     #     tempo_meses = tempo.replace("meses","")
     #     df.loc[index,'intervalo_sintomas_primeira_consulta'] = tempo_meses


    # df["intervalo_sintomas_primeira_consulta"] = pd.to_numeric(
    #     df["intervalo_sintomas_primeira_consulta"],
    #     errors="coerce"
    # )
    # df["intervalo_sintomas_primeira_consulta"] = (
    #     df["intervalo_sintomas_primeira_consulta"].astype("Int64")
    # )

# %%
new_df = limpa_dados(df)
new_df
# Out:
# batman 54 meses
# 54 meses
# batman 5 meses
# 5 meses
# batman 13 meses
# 13 meses
# batman 34 meses
# 34 meses
# batman 20 meses
# 20 meses
# batman 44 meses
# 44 meses
# batman 34 meses
# 34 meses
# batman 4 meses
# 4 meses
# batman 93 meses
# 93 meses
# batman 12 meses
# 12 meses
# batman 16 meses
# 16 meses
# batman 9 meses
# 9 meses
# batman 2 meses
# 2 meses
# batman 21 meses
# 21 meses
# batman 8 meses
# 8 meses
# batman 11 meses
# 11 meses
# batman 7meses
# 7meses
# batman 4 meses
# 4 meses
# batman 9 meses
# 9 meses
# batman 12 meses
# 12 meses
# batman 12 meses
# 12 meses
# batman 42 meses
# 42 meses
# batman 3 meses
# 3 meses
# batman 11 meses
# 11 meses
# batman 9 meses
# 9 meses
# batman 12 meses
# 12 meses
# batman 38 meses
# 38 meses
# batman 21 meses
# 21 meses
# batman 3 meses
# 3 meses
# batman 8 meses
# 8 meses
# batman 36 meses
# 36 meses
# batman 126 meses
# 126 meses
# batman 3 meses
# 3 meses
# batman 5 meses
# 5 meses
# batman 23 meses
# 23 meses
# batman 20 meses
# 20 meses
# batman 6 meses
# 6 meses
# batman 15 meses
# 15 meses
# batman 9 meses
# 9 meses
# batman 14 meses
# 14 meses
# batman 25 meses
# 25 meses
# batman 30 meses
# 30 meses
# batman ?
# ?
# batman 56 meses
# 56 meses
# batman 76 meses
# 76 meses
# batman 1 mês
# 1 mês
# batman 37 meses
# 37 meses
# batman 14 meses
# 14 meses
# batman 27 meses
# 27 meses
# batman 4 meses
# 4 meses
# batman 15 meses
# 15 meses
# batman 16 meses
# 16 meses
# batman 7 meses
# 7 meses
# batman 2 meses
# 2 meses
# batman 26 meses
# 26 meses
# batman 1 mês
# 1 mês
# batman 2 meses
# 2 meses
# batman 8 meses
# 8 meses
# batman 16 meses
# 16 meses
# batman 2 meses
# 2 meses
# batman 29 meses
# 29 meses
# batman 103 meses
# 103 meses
# batman 36 meses
# 36 meses
# batman 11 meses
# 11 meses
# batman 6 meses
# 6 meses
# batman 12 meses
# 12 meses
# batman 4 meses
# 4 meses
# batman 14 meses
# 14 meses
# batman 24 meses
# 24 meses
# batman 4 meses
# 4 meses
# batman 10 meses
# 10 meses
# batman 26 meses
# 26 meses
# batman 22 meses
# 22 meses
# batman 68 meses
# 68 meses
# batman 2 meses
# 2 meses
# batman 68 meses
# 68 meses
# batman 34 meses
# 34 meses
# batman 19 meses
# 19 meses
# batman 4 meses
# 4 meses
# batman 8 meses
# 8 meses
# batman 37 meses
# 37 meses
# batman 3 meses
# 3 meses
# batman 2 meses
# 2 meses
# batman 11 meses
# 11 meses
# batman 8 meses
# 8 meses
# batman 33 meses
# 33 meses
# batman 3 meses
# 3 meses
# batman 28 meses
# 28 meses
# batman 3 meses
# 3 meses
# batman 17 meses
# 17 meses
# batman 4 meses
# 4 meses
# batman 3 meses
# 3 meses
# batman 9 meses
# 9 meses
# batman 24 meses
# 24 meses
# batman 17 meses
# 17 meses
# batman 132 meses
# 132 meses
# batman 26 meses
# 26 meses
# batman 4 meses
# 4 meses
# batman 3 meses
# 3 meses
# batman 11 meses
# 11 meses
# batman 35 meses
# 35 meses
#     classificacao_idade data_nascimento data_primeira_consulta  \
# 0               VEOIBD       27/09/2013             02/03/2023
# 1                VEOIBD      25/10/2024             09/06/2026
# 2                DI Ped      01/01/2006             04/05/2021
# 3               VEOIBD       19/04/2019             03/08/2023
# 4        Início precoce      18/05/2012             19/01/2023
# ..                  ...             ...                    ...
# 96       Início precoce      08/08/2012             20/10/2022
# 97       Início precoce      05/03/2004             19/07/2011
# 98               DI Ped      25/04/2008             05/01/2021
# 99              VEOIBD       19/05/2017             11/03/2022
# 100             VEOIBD       13/10/2022             26/02/2026
#
#      intervalo_sintomas_primeira_consulta sexo           tipo perda_peso  \
# 0                                    54.0    F   Enterorragia        não
# 1                                     5.0    F   Enterorragia        Não
# 2                                    13.0    F  Dor abdominal        Não
# 3                                    34.0    F       Diarreia        Não
# 4                                    20.0    F          Febre        sim
# ..                                    ...  ...            ...        ...
# 96                                   26.0    M  Dor abdominal        Sim
# 97                                    4.0    M       Diarreia        Não
# 98                                    3.0    F       Diarreia        Não
# 99                                   11.0    F   Enterorragia        Sim
# 100                                  35.0    M   Enterorragia        Não
#
#     intervalo_nascimento_sintomas data_primeira_colonoscopia  \
# 0                              60                 15/07/2019
# 1                              14                 20/05/2026
# 2                             168                 13/04/2020
# 3                              18                 01/05/2022
# 4                             108                 26/01/2023
# ..                            ...                        ...
# 96                             96                 01/09/2022
# 97                             84                 01/06/2011
# 98                            144                 26/10/2020
# 99                             47                 29/09/2021
# 100                             5                 27/07/2024
#
#     intervalo_sintomas_primeira_colonoscopia classificacao
# 0                                    6 meses            CU
# 1                                    4 meses           CNC
# 2                                      1 mês            DC
# 3                                   19 meses           CNC
# 4                                   30 meses            DC
# ..                                       ...           ...
# 96                                  25 meses            DC
# 97                                   3 meses            DC
# 98                                     1 mês            DC
# 99                                   5 meses            DC
# 100                                 16 meses           CNC
#
# [101 rows x 11 columns]

# %%
new_df
# Out:
#     classificacao_idade data_nascimento data_primeira_consulta  \
# 0               VEOIBD       27/09/2013             02/03/2023
# 1                VEOIBD      25/10/2024             09/06/2026
# 2                DI Ped      01/01/2006             04/05/2021
# 3               VEOIBD       19/04/2019             03/08/2023
# 4        Início precoce      18/05/2012             19/01/2023
# ..                  ...             ...                    ...
# 96       Início precoce      08/08/2012             20/10/2022
# 97       Início precoce      05/03/2004             19/07/2011
# 98               DI Ped      25/04/2008             05/01/2021
# 99              VEOIBD       19/05/2017             11/03/2022
# 100             VEOIBD       13/10/2022             26/02/2026
#
#      intervalo_sintomas_primeira_consulta sexo           tipo perda_peso  \
# 0                                    54.0    F   Enterorragia        não
# 1                                     5.0    F   Enterorragia        Não
# 2                                    13.0    F  Dor abdominal        Não
# 3                                    34.0    F       Diarreia        Não
# 4                                    20.0    F          Febre        sim
# ..                                    ...  ...            ...        ...
# 96                                   26.0    M  Dor abdominal        Sim
# 97                                    4.0    M       Diarreia        Não
# 98                                    3.0    F       Diarreia        Não
# 99                                   11.0    F   Enterorragia        Sim
# 100                                  35.0    M   Enterorragia        Não
#
#     intervalo_nascimento_sintomas data_primeira_colonoscopia  \
# 0                              60                 15/07/2019
# 1                              14                 20/05/2026
# 2                             168                 13/04/2020
# 3                              18                 01/05/2022
# 4                             108                 26/01/2023
# ..                            ...                        ...
# 96                             96                 01/09/2022
# 97                             84                 01/06/2011
# 98                            144                 26/10/2020
# 99                             47                 29/09/2021
# 100                             5                 27/07/2024
#
#     intervalo_sintomas_primeira_colonoscopia classificacao
# 0                                    6 meses            CU
# 1                                    4 meses           CNC
# 2                                      1 mês            DC
# 3                                   19 meses           CNC
# 4                                   30 meses            DC
# ..                                       ...           ...
# 96                                  25 meses            DC
# 97                                   3 meses            DC
# 98                                     1 mês            DC
# 99                                   5 meses            DC
# 100                                 16 meses           CNC
#
# [101 rows x 11 columns]

# %%
# Posteriormente transformar todo esse codigo em uma funcaozinha (PIPELINE)
df.columns = (
    df.columns.astype(str)
    .str.replace("\n", " ", regex=False)
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)
# Renomeado as colunas
df = df.rename(columns={
    "Nome": "nome",
    "Class. Por idade": "classificacao_idade",
    "Data nascimento": "data_nascimento",
    "Data 1ª consulta": "data_primeira_consulta",
    "Tempo entre início dos sintomas e primeira consulta": "intervalo_sintomas_primeira_consulta",
    "Sexo": "sexo",
    "Tipo": "tipo",
    "Perda de peso": "perda_peso",
    "Idade (meses) início dos sintomas": "intervalo_nascimento_sintomas",
    "Data 1ª colono": "data_primeira_colonoscopia",
    "Unnamed: 10": "intervalo_sintomas_primeira_colonoscopia",
    "Classificação": "classificacao",
})

# ordenar tambem a disposicao das colunas 

df = df.drop(index=0).reset_index(drop=True)

colunas_data = ["data_nascimento", "data_primeira_consulta", "data_primeira_colonoscopia"]

for col in colunas_data:
    df[col] = pd.to_datetime(df[col], errors="coerce").dt.strftime("%d/%m/%Y")

df = df.drop(columns=["nome"])

for index,tempo in enumerate(df['intervalo_sintomas_primeira_consulta'].tolist()) : 
     tempo_meses = tempo.replace("meses","")
     df.loc[index,'intervalo_sintomas_primeira_consulta'] = tempo_meses


df["intervalo_sintomas_primeira_consulta"] = pd.to_numeric(
    df["intervalo_sintomas_primeira_consulta"],
    errors="coerce"
)
df["intervalo_sintomas_primeira_consulta"] = (
    df["intervalo_sintomas_primeira_consulta"].astype("Int64")
)

# %%
# df.head(5)

# %%
# Criar uma nova coluna data inicio sintomas

# DATA INICICO SINTOMAS =. DATA NASCIMENTO + TEMPO EM MESES

# %% [markdown]
# ## Criando a coluna data_inicio_sintomas

# %%
datas = pd.to_datetime(df["data_nascimento"], format="%d/%m/%Y", errors="coerce")
meses = df["intervalo_nascimento_sintomas"]

df["data_inicio_sintomas"] = [
    d + pd.DateOffset(months=int(m)) if pd.notna(d) and pd.notna(m) else pd.NaT
    for d, m in zip(datas, meses)
]
df['data_inicio_sintomas'] = pd.to_datetime(df['data_inicio_sintomas'], errors="coerce").dt.strftime("%d/%m/%Y")

# %%
df[['data_nascimento','intervalo_nascimento_sintomas','data_inicio_sintomas']]
# Out:
#     data_nascimento intervalo_nascimento_sintomas data_inicio_sintomas
# 0        27/09/2013                            60           27/09/2018
# 1        25/10/2024                            14           25/12/2025
# 2        01/01/2006                           168           01/01/2020
# 3        19/04/2019                            18           19/10/2020
# 4        18/05/2012                           108           18/05/2021
# ..              ...                           ...                  ...
# 96       08/08/2012                            96           08/08/2020
# 97       05/03/2004                            84           05/03/2011
# 98       25/04/2008                           144           25/04/2020
# 99       19/05/2017                            47           19/04/2021
# 100      13/10/2022                             5           13/03/2023
#
# [101 rows x 3 columns]

# %%
# RECRIAR A COLUNA Tempo entre inicio dos sintomas e 1ª colono = DATA 1 COLO - DATA INICICO SINTOMAS
# recriar essa coluna intervalo_sintomas_primeira_colonoscopia

# %%
df.head(5)
# Out:
#   classificacao_idade data_nascimento data_primeira_consulta  \
# 0             VEOIBD       27/09/2013             02/03/2023
# 1              VEOIBD      25/10/2024             09/06/2026
# 2              DI Ped      01/01/2006             04/05/2021
# 3             VEOIBD       19/04/2019             03/08/2023
# 4      Início precoce      18/05/2012             19/01/2023
#
#    intervalo_sintomas_primeira_consulta sexo           tipo perda_peso  \
# 0                                    54    F   Enterorragia        não
# 1                                     5    F   Enterorragia        Não
# 2                                    13    F  Dor abdominal        Não
# 3                                    34    F       Diarreia        Não
# 4                                    20    F          Febre        sim
#
#   intervalo_nascimento_sintomas data_primeira_colonoscopia  \
# 0                            60                 15/07/2019
# 1                            14                 20/05/2026
# 2                           168                 13/04/2020
# 3                            18                 01/05/2022
# 4                           108                 26/01/2023
#
#   intervalo_sintomas_primeira_colonoscopia classificacao data_inicio_sintomas
# 0                                  6 meses            CU           27/09/2018
# 1                                  4 meses           CNC           25/12/2025
# 2                                    1 mês            DC           01/01/2020
# 3                                 19 meses           CNC           19/10/2020
# 4                                 30 meses            DC           18/05/2021

# %%
# Com base nessas duas colunas criar a nova coluna
# intervalo_primeira_colonoscopia_inicio_sintomas

# df['intervalo_primeira_colonoscopia_inicio_sintomas'] = 
# df['data_primeira_colonoscopia'] - df['data_inicio_sintomas'] 

# df[['data_primeira_colonoscopia','data_inicio_sintomas']]

# resultados = []
for index in range(0,101):   
    
    data_primeira_colonoscopia=df.loc[index,'data_primeira_colonoscopia']
    data_inicio_sintomas =  df.loc[index,'data_inicio_sintomas']
    
    print(data_inicio_sintomas  + ' ---  ' +data_primeira_colonoscopia)
# Out:
# 27/09/2018 ---15/07/2019
# 25/12/2025 ---20/05/2026
# 01/01/2020 ---13/04/2020
# 19/10/2020 ---01/05/2022
# 18/05/2021 ---26/01/2023
# 11/06/2014 ---25/02/2016
# 30/05/2020 ---25/10/2022
# 30/06/2018 ---14/06/2018
# 02/06/2014 ---17/10/2018
# 01/03/2020 ---18/06/2020
# 24/01/2019 ---19/12/2019
# 15/12/2021 ---10/08/2022
# 04/08/2022 ---04/09/2022
# 11/10/2022 ---22/11/2023
# 19/12/2022 ---28/04/2023
# 10/02/2023 ---06/11/2023
# 19/09/2023 ---17/01/2024
# 20/09/2021 ---04/01/2022
# 30/06/2024 ---27/08/2025
# 14/12/2018 ---01/05/2019
# 14/09/2023 ---26/06/2024
# 12/01/2016 ---02/09/2019
# 05/04/2009 ---20/07/2009
# 19/05/2014 ---12/03/2015
# 12/11/2017 ---01/06/2018
# 25/08/2015 ---01/01/2016
# 10/08/2017 ---27/02/2018
# 09/07/2022 ---10/11/2022
# 17/03/2020 ---13/08/2020
# 25/05/2021 ---29/12/2021
# 19/08/2018 ---01/12/2020
# 13/09/2011 ---08/07/2018
# 23/07/2023 ---06/09/2024
# 17/04/2012 ---09/12/2013
# 09/11/2020 ---02/02/2022
# 10/06/2021 ---10/12/2021
# 25/04/2023 ---27/11/2023
# 21/06/2024 ---01/11/2024
# 08/10/2023 ---03/09/2025
# 21/06/2009 ---10/08/2010
# 10/12/2020 ---01/04/2021
# 18/09/2018 ---01/06/2020
# 31/01/2015 ---01/02/2015
# 25/02/2015 ---08/02/2021
# 03/09/2016 ---10/11/2018
# 25/07/2020 ---12/11/2020
# 29/12/2014 ---15/10/2015
# 29/01/2022 ---13/01/2023
# 13/10/2022 ---20/03/2024
# 21/07/2021 ---11/10/2021
# 12/09/2020 ---16/09/2021
# 17/05/2021 ---02/06/2022
# 03/02/2021 ---15/09/2021
# 29/05/2024 ---11/10/2024
# 27/03/2020 ---13/05/2021
# 27/08/2018 ---14/08/2019
# 12/07/2018 ---14/12/2018
# 09/08/2018 ---12/04/2019
# 20/02/2024 ---04/04/2025
# 29/09/2020 ---30/11/2020
# 08/08/2012 ---03/11/2014
# 12/06/2016 ---01/06/2017
# 19/11/2020 ---12/05/2023
# 17/12/2023 ---21/05/2024
# 27/12/2024 ---20/08/2025
# 23/07/2020 ---15/10/2021
# 13/05/2024 ---21/08/2024
# 07/01/2024 ---03/02/2025
# 01/08/2019 ---29/07/2020
# 28/09/2019 ---20/05/2020
# 07/10/2021 ---19/01/2023
# 24/09/2012 ---01/11/2012
# 23/07/2015 ---31/08/2017
# 21/11/2021 ---01/05/2024
# 03/02/2025 ---25/09/2025
# 22/03/2014 ---03/07/2015
# 17/04/2016 ---01/09/2022
# 05/03/2020 ---17/05/2022
# 03/08/2019 ---10/10/2019
# 03/09/2018 ---29/04/2019
# 12/09/2021 ---25/03/2024
# 08/07/2023 ---30/11/2023
# 14/03/2023 ---25/04/2023
# 20/10/2022 ---31/07/2023
# 29/03/2022 ---13/02/2023
# 04/04/2023 ---06/03/2025
# 17/10/2025 ---15/12/2025
# 06/01/2020 ---07/05/2022
# 17/11/2021 ---04/02/2022
# 21/02/2020 ---03/04/2021
# 18/02/2022 ---18/05/2022
# 15/11/2024 ---14/04/2025
# 28/02/2021 ---01/10/2021
# 03/04/2016 ---13/02/2019
# 09/06/2012 ---10/09/2013
# 04/01/2007 ---22/05/2015
# 08/08/2020 ---01/09/2022
# 05/03/2011 ---01/06/2011
# 25/04/2020 ---26/10/2020
# 19/04/2021 ---29/09/2021
# 13/03/2023 ---27/07/2024

# %%
df.to_csv('dataframe_limpo.csv', index=False)

# %%
from datetime import datetime

resultados = []
for index in range(len(df)):
    d1_str = df.loc[index, "data_inicio_sintomas"]
    d2_str = df.loc[index, "data_primeira_colonoscopia"]

    # 1) converte para datetime
    try:
        d1 = datetime.strptime(d1_str, "%d/%m/%Y")
        d2 = datetime.strptime(d2_str, "%d/%m/%Y")
    except (ValueError, TypeError):
        resultados.append(None)
        continue

    # 2) valida ordem
    if d2 <= d1:
        resultados.append(None)
        continue

    # 3) calcula meses completos
    meses = (d2.year - d1.year) * 12 + (d2.month - d1.month) - (d2.day < d1.day)
    resultados.append(meses)

df["intervalo_sintomas_primeira_colo2"] = resultados

# %%
# df[['data_inicio_sintomas','intervalo_sintomas_primeira_colo2','data_primeira_colonoscopia']]

# %%
len(df[df['intervalo_sintomas_primeira_colo2'] == 0])
# Out:
# 1
